# %%
from obspy.core import UTCDateTime
from obspy.clients.fdsn import Client

# %matplotlib inline

# %%
t = UTCDateTime('2018-01-28T09:10:40')

client = Client('IRIS')
st = client.get_waveforms('IU', 'HNR', '00', 'BHZ', t, t + 60)

# %%
st.plot()
